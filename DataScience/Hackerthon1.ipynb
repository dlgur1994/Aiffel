# %% [markdown]
# ## Plan
#
# - preprocess
#     - 하나의 파일로 만들기
#         - submission.csv에는 air id가 있기 때문에 데이터의 기준은 air
#         - hpg 이름을 air로 바꾸기 (store_id_relation.csv 이용)
#         - 하나의 csv 파일로 바꾸기 (air의 reserve visitor를 float값으로 변경)
#         - 요일, holiday flag column 추가
#         - 식당 genre, area column 추가
#         - air_visit_data 이용해서 워크인 count
#
#     - feature 찾기
#         - one-hot encoding (요일, 식당 genre, area)
#         - 분포 확인 (로그 변환 사용)
#         - 상관도 검색
#
# - train
#     - train : val = 8 : 2
#     - 여러 모델 테스트 (앙상블 사용 예상)
#     - 하이퍼 파라미터 조정
#     - RMSLE 값 기준
#
# - test
#     - 케글측에서 일부러 연휴 기간을 포함, 식당이 열지 않은 날도 있지만 최종 점수에 포함 안됨
#     - submission 파일 복사 후 날짜 분리, 사용할 feature append
#     - 예측
#     - submission 파일에 예측값 append
#     - 제출

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2498048064103512458, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11345264640
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12160447817245310802
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
11139884032
11345264640

# %% [markdown]
# # pre-processing

# %% [markdown]
# ## 데이터 합치기

# %% [markdown]
# ## 데이터 타입 맞추기

# %% [markdown]
# ## null 값 체크

# %% [markdown]
# ## 이상치 처리

# %% [markdown]
# ## one-hot encoding

# %% [markdown]
# ### 요일, 식당 genre, area, holiday_flg

# %% [markdown]
# ## 정규화

# %% [markdown]
# 전처리

# %% [markdown]
# # feature engineering

# %% [markdown]
# # 시각화

# %% [markdown]
# # 모델 학습

# %% [markdown]
# # 모델 평가

# %% [markdown]
# # code

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
import matplotlib.pyplot as plt

# %%
data = {
    'tra':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/air_visit_data.csv.zip'),
    'as':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/air_store_info.csv.zip'),
    'hs':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/hpg_store_info.csv.zip'),
    'ar':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/air_reserve.csv.zip'),
    'hr':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/hpg_reserve.csv.zip'),
    'id':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/store_id_relation.csv.zip'),
    'tes':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/sample_submission.csv.zip'),
    'hol':
    pd.read_csv('/content/drive/MyDrive/Hackathon/recruit-restaurant-visitor-forecasting/date_info.csv.zip').rename(columns={
        'calendar_date': 'visit_date'
    })
}


display(data['tra'])
display(data['as'])
display(data['hs'])
display(data['ar'])
display(data['hr'])
display(data['id'])
display(data['tes'])
display(data['hol'])

# %% [markdown]
# # Reference

# %% [markdown]
# * https://www.kaggle.com/shikhar1/combining-tables-and-data-pre-processing
# * https://www.kaggle.com/irinaabdullaeva/welcome-recruit-restaurant-visitor-forecasting
